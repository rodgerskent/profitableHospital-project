# %%
#profitableHospital-project - SVC Model

# %%
#dependencies
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, MinMaxScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.feature_selection import RFE
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import LinearRegression
from sklearn.svm import SVC 
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import classification_report
from sklearn.neighbors import KNeighborsClassifier
import tensorflow
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import joblib

# %%
#Read the main file with the targeted data set
df = pd.read_csv("mainFile4.csv")
df.head(2)
# Out:
#    Provider CCN                      Hospital Name        Street Address  \
# 0        510013         REYNOLDS MEMORIAL HOSPITAL   800 WHEELING AVENUE
# 1        340106  SANDHILLS REGIONAL MEDICAL CENTER  1000 WEST HAMLET AVE
#
#         City State Code Zip Code  CON  Urban  Inpatient %  Outpatient %  ...  \
# 0  GLEN DALE         WV    26038  1.0    1.0     0.311881      0.688119  ...
# 1     HAMLET         NC    28345  1.0    0.0     0.325730      0.674270  ...
#
#    Discharges Per Bed  Discharges Per Bed Days  Discharges Per FTE  \
# 0            6.214286                 0.067547            6.214286
# 1            3.062500                 0.050205            3.062500
#
#    Net Income %  Net Income Score   Labor %  Overhead %  Depreciation %  \
# 0      0.308395                 1  0.715116    0.627406        0.031451
# 1     -0.337043                 3  0.509928    0.924882        0.073496
#
#    Labor Exp Per FTE  Overhead Exp Per Bed
# 0       18996.972990          76691.942857
# 1       61909.838473          47792.984375
#
# [2 rows x 26 columns]

# %%
#Read the features file with the x values utilized in the earlier linear and logrithmic regression analysis
features = pd.read_csv("mainFeatures.csv")
features.head(2)
# Out:
#    CON  Urban  Inpatient %  Outpatient %  Charity %  Uncompensated %  \
# 0  1.0    1.0     0.311881      0.688119   0.003080         0.003080
# 1  1.0    0.0     0.325730      0.674270   0.001075         0.001075
#
#    Rev Per Discharge    Rev Per Bed  Rev Per Bed Days    Rev Per FTE  \
# 0       19670.239080  122236.485714       1328.657453   26564.899100
# 1       16873.362245   51674.671875        847.125768  121408.920705
#
#    Discharges Per Bed  Discharges Per Bed Days  Discharges Per FTE   Labor %  \
# 0            6.214286                 0.067547            6.214286  0.715116
# 1            3.062500                 0.050205            3.062500  0.509928
#
#    Overhead %  Depreciation %  Labor Exp Per FTE  Overhead Exp Per Bed
# 0    0.627406        0.031451       18996.972990          76691.942857
# 1    0.924882        0.073496       61909.838473          47792.984375

# %%
# df['Net Income Score'].value_counts()

# %%
y = df[['Net Income Score']]

# %%
# df['Net Income %'].value_counts()
# Out:
#  0.011300    1
#  0.106603    1
#  0.568607    1
#  0.090192    1
#  0.100417    1
#             ..
#  0.002675    1
# -0.165539    1
#  0.129859    1
#  0.004736    1
# -0.144940    1
# Name: Net Income %, Length: 2982, dtype: int64

# %%
# y = df[['Net Income %']]

# %%
X = features

# %%
#Create a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(
    X, y, random_state=1)

# %%
y_train.shape
# Out:
# (2236, 1)

# %%
X_train.shape
# Out:
# (2236, 18)

# %%
# Scale your data
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Create the SVC linear regression model
model = SVC(kernel='linear')
model
# Out:
# SVC(kernel='linear')

# %%
# Create the SVC linear regression model
# model = SVC(kernel='logrithmic')
# model

# %%
# Tune the model with GridSearchCV
param_grid = {'C': [1, 5, 10, 50],
              'gamma': [0.0001, 0.0005, 0.001, 0.005]}
gridb = GridSearchCV(model, param_grid, verbose=3)

# %%
gridb.fit(X_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ..............................C=1, gamma=0.0001; total time=   0.0s
# [CV 2/5] END ..............................C=1, gamma=0.0001; total time=   0.0s
# [CV 3/5] END ..............................C=1, gamma=0.0001; total time=   0.0s
# [CV 4/5] END ..............................C=1, gamma=0.0001; total time=   0.0s
# [CV 5/5] END ..............................C=1, gamma=0.0001; total time=   0.0s
# [CV 1/5] END ..............................C=1, gamma=0.0005; total time=   0.0s
# [CV 2/5] END ..............................C=1, gamma=0.0005; total time=   0.0s
# [CV 3/5] END ..............................C=1, gamma=0.0005; total time=   0.0s
# [CV 4/5] END ..............................C=1, gamma=0.0005; total time=   0.0s
# [CV 5/5] END ..............................C=1, gamma=0.0005; total time=   0.0s
# [CV 1/5] END ...............................C=1, gamma=0.001; total time=   0.0s
# [CV 2/5] END ...............................C=1, gamma=0.001; total time=   0.0s
# [CV 3/5] END ...............................C=1, gamma=0.001; total time=   0.0s
# [CV 4/5] END ...............................C=1, gamma=0.001; total time=   0.0s
# [CV 5/5] END ...............................C=1, gamma=0.001; total time=   0.0s
# [CV 1/5] END ...............................C=1, gamma=0.005; total time=   0.0s
# [CV 2/5] END ...............................C=1, gamma=0.005; total time=   0.0s
# [CV 3/5] END ...............................C=1, gamma=0.005; total time=   0.0s
# [CV 4/5] END ...............................C=1, gamma=0.005; total time=   0.0s
# [CV 5/5] END ...............................C=1, gamma=0.005; total time=   0.0s
# [CV 1/5] END ..............................C=5, gamma=0.0001; total time=   0.0s
# [CV 2/5] END ..............................C=5, gamma=0.0001; total time=   0.0s
# [CV 3/5] END ..............................C=5, gamma=0.0001; total time=   0.0s
# [CV 4/5] END ..............................C=5, gamma=0.0001; total time=   0.0s
# [CV 5/5] END ..............................C=5, gamma=0.0001; total time=   0.0s
# [CV 1/5] END ..............................C=5, gamma=0.0005; total time=   0.0s
# [CV 2/5] END ..............................C=5, gamma=0.0005; total time=   0.0s
# [CV 3/5] END ..............................C=5, gamma=0.0005; total time=   0.0s
# [CV 4/5] END ..............................C=5, gamma=0.0005; total time=   0.0s
# [CV 5/5] END ..............................C=5, gamma=0.0005; total time=   0.0s
# [CV 1/5] END ...............................C=5, gamma=0.001; total time=   0.0s
# [CV 2/5] END ...............................C=5, gamma=0.001; total time=   0.0s
# [CV 3/5] END ...............................C=5, gamma=0.001; total time=   0.0s
# [CV 4/5] END ...............................C=5, gamma=0.001; total time=   0.0s
# [CV 5/5] END ...............................C=5, gamma=0.001; total time=   0.0s
# [CV 1/5] END ...............................C=5, gamma=0.005; total time=   0.0s
# [CV 2/5] END ...............................C=5, gamma=0.005; total time=   0.0s
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
# ...
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py:614: FitFailedWarning: Estimator fit failed. The score on this train-test partition for these parameters will be set to nan. Details:
# Traceback (most recent call last):
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_validation.py", line 593, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 173, in fit
#     y = self._validate_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py", line 553, in _validate_targets
#     check_classification_targets(y)
#   File "C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py", line 183, in check_classification_targets
#     raise ValueError("Unknown label type: %r" % y_type)
# ValueError: Unknown label type: 'continuous'
#
#   FitFailedWarning)
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_search.py:921: UserWarning: One or more of the test scores are non-finite: [nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan nan]
#   category=UserWarning
# C:\Users\rodge\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-17-2fd5be6e2d7c> in <module>
# ----> 1 gridb.fit(X_train_scaled, y_train)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_search.py in fit(self, X, y, groups, **fit_params)
#     878             refit_start_time = time.time()
#     879             if y is not None:
# --> 880                 self.best_estimator_.fit(X, y, **fit_params)
#     881             else:
#     882                 self.best_estimator_.fit(X, **fit_params)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py in fit(self, X, y, sample_weight)
#     171                                        accept_large_sparse=False)
#     172
# --> 173         y = self._validate_targets(y)
#     174
#     175         sample_weight = np.asarray([]
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py in _validate_targets(self, y)
#     551     def _validate_targets(self, y):
#     552         y_ = column_or_1d(y, warn=True)
# --> 553         check_classification_targets(y)
#     554         cls, y = np.unique(y_, return_inverse=True)
#     555         self.class_weight_ = compute_class_weight(self.class_weight,
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\multiclass.py in check_classification_targets(y)
#     181     if y_type not in ['binary', 'multiclass', 'multiclass-multioutput',
#     182                       'multilabel-indicator', 'multilabel-sequences']:
# --> 183         raise ValueError("Unknown label type: %r" % y_type)
#     184
#     185
#
# ValueError: Unknown label type: 'continuous'

# %%
print(gridb.best_params_)
print(gridb.best_score_)
# Out:
# {'C': 1, 'gamma': 0.0001}
# nan

# %%
predictions = gridb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-19-b9955e06d3ab> in <module>
# ----> 1 predictions = gridb.predict(X_test)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     118
#     119         # lambda, but not partial, allows help() to work with update_wrapper
# --> 120         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     121         # update the docstring of the returned function
#     122         update_wrapper(out, self.fn)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\model_selection\_search.py in predict(self, X)
#     538         """
#     539         self._check_is_fitted('predict')
# --> 540         return self.best_estimator_.predict(X)
#     541
#     542     @if_delegate_has_method(delegate=('best_estimator_', 'estimator'))
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     622             y = np.argmax(self.decision_function(X), axis=1)
#     623         else:
# --> 624             y = super().predict(X)
#     625         return self.classes_.take(np.asarray(y, dtype=np.intp))
#     626
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py in predict(self, X)
#     340         y_pred : ndarray of shape (n_samples,)
#     341         """
# --> 342         X = self._validate_for_predict(X)
#     343         predict = self._sparse_predict if self._sparse else self._dense_predict
#     344         return predict(X)
#
# ~\anaconda3\envs\PythonData\lib\site-packages\sklearn\svm\_base.py in _validate_for_predict(self, X)
#     490                                  "the number of samples at training time" %
#     491                                  (X.shape[1], self.shape_fit_[0]))
# --> 492         elif not callable(self.kernel) and X.shape[1] != self.shape_fit_[1]:
#     493             raise ValueError("X.shape[1] = %d should be equal to %d, "
#     494                              "the number of features at training time" %
#
# AttributeError: 'SVC' object has no attribute 'shape_fit_'

# %%
# Calculate classification report
print(classification_report(y_test, predictions,
                            target_names=["3", "2" , "1"]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-0cd4e7b9ba26> in <module>
#       1 # Calculate classification report
# ----> 2 print(classification_report(y_test, predictions,
#       3                             target_names=["3", "2" , "1"]))
#
# NameError: name 'predictions' is not defined
